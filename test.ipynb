# %%
import flickrapi
import random
import requests
from PIL import Image
from IPython import display
import os
from mosaic.models import Pic
api_key = '5f0a0c4e04298e2e84ef379f8de4a7fe'
api_secret = 'df521e620606493c'


flickr = flickrapi.FlickrAPI(api_key, api_secret)
try:
    os.mkdir('flickr_photo')
except OSError:
    pass

# %%
photos = flickr.photos.search(
    page=random.randint(0, 100),
    tags='red',
    width=1920,
    orientation='landscape',
    content_type=1,
    sort='relevance',
    license='9,10',
    format='parsed-json')
# print(photos)

# %%
for i, photo in enumerate(photos['photos']['photo']):
    print(i)
    finded_photo = flickr.photos.getSizes(
        photo_id=photo['id'], format='parsed-json')['sizes']['size'][0]
    if finded_photo['label'] == "Square":
        print(finded_photo['source'])
        img = requests.get(finded_photo['source'])
        img_file = open(f'flickr_photo/{i}.jpg', 'wb')
        img_file.write(img.content)
        img_file.close()
    
    image = Image.open(f'flickr_photo/{i}.jpg')

    w, h = image.size
    rr, gg, bb = 0, 0, 0

    for x in range(w):
        for y in range(h):
            r, g, b = image.getpixel((x, y))
            rr += r
            gg += g
            bb += b

    cnt = w * h
    print(rr//cnt, gg//cnt, bb//cnt)
    try:
        pic = Pic(url=finded_photo['source'], r=rr//cnt, g=gg//cnt, b=bb//cnt)
        pic.save()
    except Exception as e:
        print(e)
    awg_color = Image.new('RGB', (150, 75), color=(rr//cnt, gg//cnt, bb//cnt))
    awg_color.paste(image, (0, 0, 75, 75))
    awg_color.save(f'flickr_photo/awg_{i}.jpg', "JPEG")
    image = display.Image(f'flickr_photo/{i}.jpg')
    awg_color = display.Image(f'flickr_photo/awg_{i}.jpg')
    display.display_jpeg(awg_color)
print("ok")
# Out:
# 0
# https://live.staticflickr.com/2811/12858957104_372c68178e_s.jpg
# 139 138 134
# You cannot call this from an async context - use a thread or sync_to_async.
# 1
# https://live.staticflickr.com/3834/12858944844_9892ce1e92_s.jpg
# 141 125 128
# You cannot call this from an async context - use a thread or sync_to_async.
# 2
# https://live.staticflickr.com/2846/12858528095_43053ce4ae_s.jpg
# 109 108 107
# You cannot call this from an async context - use a thread or sync_to_async.
# 3
# https://live.staticflickr.com/8495/8256977593_0f18fbeb1b_s.jpg
# 192 160 129
# You cannot call this from an async context - use a thread or sync_to_async.
# 4
# https://live.staticflickr.com/65535/49399444602_c526649b0f_s.jpg
# 111 113 109
# You cannot call this from an async context - use a thread or sync_to_async.
# 5
# https://live.staticflickr.com/65535/49387685338_dda037df93_s.jpg
# 134 73 64
# You cannot call this from an async context - use a thread or sync_to_async.
# 6
# https://live.staticflickr.com/65535/49388159361_2936523b67_s.jpg
# 108 63 61
# You cannot call this from an async context - use a thread or sync_to_async.
# 7
# https://live.staticflickr.com/65535/49369212676_b409fd8ef7_s.jpg
# 108 89 80
# You cannot call this from an async context - use a thread or sync_to_async.
# 8
# https://live.staticflickr.com/65535/49314084493_6ee72da80d_s.jpg
# 52 50 50
# You cannot call this from an async context - use a thread or sync_to_async.
# 9
# https://live.staticflickr.com/65535/49304191318_9075d5446f_s.jpg
# 185 58 70
# You cannot call this from an async context - use a thread or sync_to_async.
# 10
# https://live.staticflickr.com/65535/49302467181_13245b900d_s.jpg
# 63 59 54
# You cannot call this from an async context - use a thread or sync_to_async.
# 11
# https://live.staticflickr.com/65535/49293926726_bcc7f32c82_s.jpg
# 144 133 127
# You cannot call this from an async context - use a thread or sync_to_async.
# 12
# https://live.staticflickr.com/65535/49293924826_b34b6fb244_s.jpg
# 93 87 71
# You cannot call this from an async context - use a thread or sync_to_async.
# 13
# https://live.staticflickr.com/65535/49293920576_2b51df750a_s.jpg
# 147 143 132
# You cannot call this from an async context - use a thread or sync_to_async.
# 14
# https://live.staticflickr.com/65535/49293920126_77b597556e_s.jpg
# 143 131 118
# You cannot call this from an async context - use a thread or sync_to_async.
# 15
# https://live.staticflickr.com/65535/49293916951_c4d516d847_s.jpg
# 161 151 137
# You cannot call this from an async context - use a thread or sync_to_async.
# 16
# https://live.staticflickr.com/65535/49294107907_a4886799e1_s.jpg
# 81 72 61
# You cannot call this from an async context - use a thread or sync_to_async.
# 17
# https://live.staticflickr.com/65535/49293910966_6053603066_s.jpg
# 82 7363
# You cannot call this from an async context - use a thread or sync_to_async.
# 18
# https://live.staticflickr.com/65535/49293419163_002b2ccebd_s.jpg
# 83 75 65
# You cannot call this from an async context - use a thread or sync_to_async.
# 19
# https://live.staticflickr.com/65535/49293909551_c5291ea46a_s.jpg
# 86 78 67
# You cannot call this from an async context - use a thread or sync_to_async.
# 20
# https://live.staticflickr.com/65535/49293907606_97dfa50824_s.jpg
# 85 79 66
# You cannot call this from an async context - use a thread or sync_to_async.
# 21
# https://live.staticflickr.com/65535/49294102232_a380f92587_s.jpg
# 151 151 140
# You cannot call this from an async context - use a thread or sync_to_async.
# 22
# https://live.staticflickr.com/65535/49293905986_0283b9b1b9_s.jpg
# 151 151 139
# You cannot call this from an async context - use a thread or sync_to_async.
# 23
# https://live.staticflickr.com/65535/49293904191_184a06c22d_s.jpg
# 143 140 114
# You cannot call this from an async context - use a thread or sync_to_async.
# 24
# https://live.staticflickr.com/65535/49294097257_0ddbfbdfaa_s.jpg
# 141 136 112
# You cannot call this from an async context - use a thread or sync_to_async.
# 25
# https://live.staticflickr.com/65535/49293896346_389d6dfd98_s.jpg
# 116 116 84
# You cannot call this from an async context - use a thread or sync_to_async.
# 26
# https://live.staticflickr.com/65535/49293889591_e36833bb50_s.jpg
# 104 107 62
# You cannot call this from an async context - use a thread or sync_to_async.
# 27
# https://live.staticflickr.com/65535/49293397118_76081817df_s.jpg
# 159 152 146
# You cannot call this from an async context - use a thread or sync_to_async.
# 28
# https://live.staticflickr.com/65535/49293886846_ec0f37fbdb_s.jpg
# 85 81 75
# You cannot call this from an async context - use a thread or sync_to_async.
# 29
# https://live.staticflickr.com/65535/49294081222_5c6367918a_s.jpg
# 86 95 94
# You cannot call this from an async context - use a thread or sync_to_async.
# 30
# https://live.staticflickr.com/65535/49294080632_2456f83873_s.jpg
# 82 96 98
# You cannot call this from an async context - use a thread or sync_to_async.
# 31
# https://live.staticflickr.com/65535/49293870861_4fa6ae4461_s.jpg
# 111 124 64
# You cannot call this from an async context - use a thread or sync_to_async.
# 32
# https://live.staticflickr.com/65535/49294065192_8861a45728_s.jpg
# 113 125 66
# You cannot call this from an async context - use a thread or sync_to_async.
# 33
# https://live.staticflickr.com/65535/49294060587_edbf494db7_s.jpg
# 152 151 136
# You cannot call this from an async context - use a thread or sync_to_async.
# 34
# https://live.staticflickr.com/65535/49293369513_90f7739943_s.jpg
# 124 124 84
# You cannot call this from an async context - use a thread or sync_to_async.
# 35
# https://live.staticflickr.com/65535/49294054637_56e95b23a9_s.jpg
# 112 109 60
# You cannot call this from an async context - use a thread or sync_to_async.
# 36
# https://live.staticflickr.com/65535/49293858776_584dca082f_s.jpg
# 117 114 66
# You cannot call this from an async context - use a thread or sync_to_async.
# 37
# https://live.staticflickr.com/65535/49293360113_533173199e_s.jpg
# 137 134 92
# You cannot call this from an async context - use a thread or sync_to_async.
# 38
# https://live.staticflickr.com/65535/49293852751_e8ee4ac59d_s.jpg
# 125 123 87
# You cannot call this from an async context - use a thread or sync_to_async.
# 39
# https://live.staticflickr.com/65535/49293358513_78be96078f_s.jpg
# 130 128 94
# You cannot call this from an async context - use a thread or sync_to_async.
# 40
# https://live.staticflickr.com/65535/49294046497_9b6d9ca324_s.jpg
# 129 127 93
# You cannot call this from an async context - use a thread or sync_to_async.
# 41
# https://live.staticflickr.com/65535/49293850796_57365814d1_s.jpg
# 128 126 91
# You cannot call this from an async context - use a thread or sync_to_async.
# 42
# https://live.staticflickr.com/65535/49293850166_9a6bde5579_s.jpg
# 122 118 75
# You cannot call this from an async context - use a thread or sync_to_async.
# 43
# https://live.staticflickr.com/65535/49293356138_49a9a1ede2_s.jpg
# 121 118 75
# You cannot call this from an async context - use a thread or sync_to_async.
# 44
# https://live.staticflickr.com/65535/49293354728_0d554421b6_s.jpg
# 123 120 78
# You cannot call this from an async context - use a thread or sync_to_async.
# 45
# https://live.staticflickr.com/65535/49294041772_2ab2e3a89c_s.jpg
# 128 126 81
# You cannot call this from an async context - use a thread or sync_to_async.
# 46
# https://live.staticflickr.com/65535/49292577742_5018f7211d_s.jpg
# 98 104 117
# You cannot call this from an async context - use a thread or sync_to_async.
# 47
# https://live.staticflickr.com/65535/49290806087_07155d482a_s.jpg
# 123 123 123
# You cannot call this from an async context - use a thread or sync_to_async.
# 48
# https://live.staticflickr.com/65535/49279976481_ef2ac0fcdd_s.jpg
# 163 102 84
# You cannot call this from an async context - use a thread or sync_to_async.
# 49
# https://live.staticflickr.com/65535/49223593743_55a6edd209_s.jpg
# 106 112 127
# You cannot call this from an async context - use a thread or sync_to_async.
# 50
# https://live.staticflickr.com/65535/49215368932_b1119d1519_s.jpg
# 98 61 56
# You cannot call this from an async context - use a thread or sync_to_async.
# 51
# https://live.staticflickr.com/65535/49203432328_c9aa56e612_s.jpg
# 95 97 24
# You cannot call this from an async context - use a thread or sync_to_async.
# 52
# https://live.staticflickr.com/65535/49187991957_f13fb91fe4_s.jpg
# 104 55 41
# You cannot call this from an async context - use a thread or sync_to_async.
# 53
# https://live.staticflickr.com/65535/49186461046_6069334c7c_s.jpg
# 163 46 51
# You cannot call this from an async context - use a thread or sync_to_async.
# 54
# https://live.staticflickr.com/65535/49183338638_0cfb42eb2f_s.jpg
# 118 69 35
# You cannot call this from an async context - use a thread or sync_to_async.
# 55
# https://live.staticflickr.com/65535/49181500738_32625eb753_s.jpg
# 108 84 36
# You cannot call this from an async context - use a thread or sync_to_async.
# 56
# https://live.staticflickr.com/65535/49181990142_2398ac2b69_s.jpg
# 90 94 29
# You cannot call this from an async context - use a thread or sync_to_async.
# 57
# https://live.staticflickr.com/65535/49181784792_fbef5d40d0_s.jpg
# 108 110 43
# You cannot call this from an async context - use a thread or sync_to_async.
# 58
# https://live.staticflickr.com/65535/49175119143_4ac58f59ef_s.jpg
# 66 72 42
# You cannot call this from an async context - use a thread or sync_to_async.
# 59
# https://live.staticflickr.com/7321/10009057573_230cc114b3_s.jpg
# 104 114 131
# You cannot call this from an async context - use a thread or sync_to_async.
# 60
# https://live.staticflickr.com/8528/8642662453_74dff7e352_s.jpg
# 147 143 133
# You cannot call this from an async context - use a thread or sync_to_async.
# 61
# https://live.staticflickr.com/8396/8643754638_45baf9f779_s.jpg
# 131 131 133
# You cannot call this from an async context - use a thread or sync_to_async.
# 62
# https://live.staticflickr.com/8382/8475068670_0c53b0e1a1_s.jpg
# 137 82 80
# You cannot call this from an async context - use a thread or sync_to_async.
# 63
# https://live.staticflickr.com/7153/6733211479_2859cfe669_s.jpg
# 131 110 104
# You cannot call this from an async context - use a thread or sync_to_async.
# 64
# https://live.staticflickr.com/6113/6326468205_946cae49f3_s.jpg
# 122 132 137
# You cannot call this from an async context - use a thread or sync_to_async.
# 65
# https://live.staticflickr.com/5162/5267596713_5124661d4f_s.jpg
# 37 37 40
# You cannot call this from an async context - use a thread or sync_to_async.
# 66
# https://live.staticflickr.com/2583/4124291919_82374432b0_s.jpg
# 81 74 74
# You cannot call this from an async context - use a thread or sync_to_async.
# 67
# https://live.staticflickr.com/3178/2849472665_6c3d3d7213_s.jpg
# 110 102 24
# You cannot call this from an async context - use a thread or sync_to_async.
# 68
# https://live.staticflickr.com/65535/49293407468_81da466005_s.jpg
# 143 142 118
# You cannot call this from an async context - use a thread or sync_to_async.
# 69
# https://live.staticflickr.com/65535/49293892881_c2f209f1df_s.jpg
# 157 153 130
# You cannot call this from an async context - use a thread or sync_to_async.
# 70
# https://live.staticflickr.com/65535/49294080002_5bcbee66cb_s.jpg
# 92 83 77
# You cannot call this from an async context - use a thread or sync_to_async.
# 71
# https://live.staticflickr.com/65535/49293392658_f908fbbe9b_s.jpg
# 106 113 71
# You cannot call this from an async context - use a thread or sync_to_async.
# 72
# https://live.staticflickr.com/65535/49293376633_34886d0db1_s.jpg
# 113 126 67
# You cannot call this from an async context - use a thread or sync_to_async.
# 73
# https://live.staticflickr.com/65535/49294055332_960c4b529b_s.jpg
# 112 109 60
# You cannot call this from an async context - use a thread or sync_to_async.
# 74
# https://live.staticflickr.com/65535/49294053417_c03c6c8543_s.jpg
# 135 131 99
# You cannot call this from an async context - use a thread or sync_to_async.
# 75
# https://live.staticflickr.com/65535/49294052447_3d1a6c7022_s.jpg
# 139 137 105
# You cannot call this from an async context - use a thread or sync_to_async.
# 76
# https://live.staticflickr.com/65535/49293355488_21879e01c6_s.jpg
# 122 119 75
# You cannot call this from an async context - use a thread or sync_to_async.
# 77
# https://live.staticflickr.com/65535/49293847646_56e11063a8_s.jpg
# 130 128 83
# You cannot call this from an async context - use a thread or sync_to_async.
# 78
# https://live.staticflickr.com/65535/49293351438_98775f9095_s.jpg
# 136 133 90
# You cannot call this from an async context - use a thread or sync_to_async.
# 79
# https://live.staticflickr.com/65535/49278732636_ed5d01a410_s.jpg
# 88 91 88
# You cannot call this from an async context - use a thread or sync_to_async.
# 80
# https://live.staticflickr.com/65535/49273511618_3be937743a_s.jpg
# 107 98 92
# You cannot call this from an async context - use a thread or sync_to_async.
# 81
# https://live.staticflickr.com/65535/49273511088_8b618edfc2_s.jpg
# 133 139 140
# You cannot call this from an async context - use a thread or sync_to_async.
# 82
# https://live.staticflickr.com/65535/49241815086_da41d6bd6b_s.jpg
# 67 70 77
# You cannot call this from an async context - use a thread or sync_to_async.
# 83
# https://live.staticflickr.com/65535/49242031822_519254c508_s.jpg
# 70 77 84
# You cannot call this from an async context - use a thread or sync_to_async.
# 84
# https://live.staticflickr.com/65535/49241814976_784724c947_s.jpg
# 70 72 79
# You cannot call this from an async context - use a thread or sync_to_async.
# 85
# https://live.staticflickr.com/65535/49189952858_e58a0ca586_s.jpg
# 67 66 72
# You cannot call this from an async context - use a thread or sync_to_async.
# 86
# https://live.staticflickr.com/65535/49189951813_c33bcccd61_s.jpg
# 156 154 127
# You cannot call this from an async context - use a thread or sync_to_async.
# 87
# https://live.staticflickr.com/65535/49186510793_64c37204ec_s.jpg
# 94 57 37
# You cannot call this from an async context - use a thread or sync_to_async.
# 88
# https://live.staticflickr.com/65535/49183051768_2897b61eef_s.jpg
# 130 72 40
# You cannot call this from an async context - use a thread or sync_to_async.
# 89
# https://live.staticflickr.com/65535/49154508726_d68ec0ff33_s.jpg
# 128 118 83
# You cannot call this from an async context - use a thread or sync_to_async.
# 90
# https://live.staticflickr.com/65535/49154716662_2144a297e8_s.jpg
# 84 75 60
# You cannot call this from an async context - use a thread or sync_to_async.
# 91
# https://live.staticflickr.com/65535/49154507921_58cdd731d5_s.jpg
# 128 125 105
# You cannot call this from an async context - use a thread or sync_to_async.
# 92
# https://live.staticflickr.com/65535/49154505141_b447b6ec2d_s.jpg
# 127 112 101
# You cannot call this from an async context - use a thread or sync_to_async.
# 93
# https://live.staticflickr.com/65535/49154003303_9776d45666_s.jpg
# 95 81 67
# You cannot call this from an async context - use a thread or sync_to_async.
# 94
# https://live.staticflickr.com/65535/49154711297_08a592eed6_s.jpg
# 100 86 72
# You cannot call this from an async context - use a thread or sync_to_async.
# 95
# https://live.staticflickr.com/65535/49154002243_e3e97e2dd6_s.jpg
# 91 77 63
# You cannot call this from an async context - use a thread or sync_to_async.
# 96
# https://live.staticflickr.com/65535/49154706217_5b22b44ccd_s.jpg
# 102 89 73
# You cannot call this from an async context - use a thread or sync_to_async.
# 97
# https://live.staticflickr.com/65535/49153996738_c96b8b6eed_s.jpg
# 122 119 94
# You cannot call this from an async context - use a thread or sync_to_async.
# 98
# https://live.staticflickr.com/65535/49154704512_65547a1952_s.jpg
# 134 129 123
# You cannot call this from an async context - use a thread or sync_to_async.
# 99
# https://live.staticflickr.com/65535/49154704182_7990aea559_s.jpg
# 107 98 91
# You cannot call this from an async context - use a thread or sync_to_async.
# ok

# %%
for i in range(100):
    pass

# %%
os.getcwd()
# Out:
# 'P:\\mosaic_photo'
